# %%
import pandas as pd

# %%
train_df = pd.read_json('traindata.json', lines=True)

# %%
train_df.head()
# Out:
#                                           annotation  \
# 0  [{'label': ['Companies worked at'], 'points': ...
# 1  [{'label': ['Companies worked at'], 'points': ...
# 2  [{'label': ['Skills'], 'points': [{'start': 22...
# 3  [{'label': ['Skills'], 'points': [{'start': 46...
# 4  [{'label': ['Skills'], 'points': [{'start': 18...
#
#                                              content
# 0  Govardhana K\nSenior Software Engineer\n\nBeng...
# 1  Harini Komaravelli\nTest Analyst at Oracle, Hy...
# 2  Hartej Kathuria\nData Analyst Intern - Oracle ...
# 3  Ijas Nizamuddin\nAssociate Consultant - State ...
# 4  Imgeeyaul Ansari\njava developer\n\nPune, Maha...

# %%
train_df.describe
# Out:
# <bound method NDFrame.describe of                                             annotation  \
# 0    [{'label': ['Companies worked at'], 'points': ...
# 1    [{'label': ['Companies worked at'], 'points': ...
# 2    [{'label': ['Skills'], 'points': [{'start': 22...
# 3    [{'label': ['Skills'], 'points': [{'start': 46...
# 4    [{'label': ['Skills'], 'points': [{'start': 18...
# 5    [{'label': ['Graduation Year'], 'points': [{'s...
# 6    [{'label': ['Graduation Year'], 'points': [{'s...
# 7    [{'label': ['Skills'], 'points': [{'start': 30...
# 8    [{'label': ['Skills'], 'points': [{'start': 21...
# 9    [{'label': ['Skills'], 'points': [{'start': 40...
# 10   [{'label': ['Skills'], 'points': [{'start': 30...
# 11   [{'label': ['Companies worked at'], 'points': ...
# 12   [{'label': ['Graduation Year'], 'points': [{'s...
# 13   [{'label': ['Skills'], 'points': [{'start': 18...
# 14   [{'label': ['Skills'], 'points': [{'start': 14...
# ...

# %%
df = pd.read_json('aggregated_hrxmls.json')

# %%
df.head()
# Out:
#                                              contact  \
# 0  {'email1': 'chandreshpas@gmail.com', 'email2':...
# 1  {'email1': 'sreenivas.smsso@gmail.com', 'email...
# 2  {'email1': 'devesh.khanjode@yahoo.com', 'email...
# 3  {'email1': '', 'email2': '', 'phone1': '+91 96...
# 4  {'email1': 'radhakrishnashpk@gmail.com', 'emai...
#
#                                            education  \
# 0  [{'degree': 'MCA', 'year': 2015, 'marks': '6.7...
# 1                                               None
# 2  [{'degree': 'B.E', 'year': 2011, 'marks': '', ...
# 3  [{'degree': 'BE  and  MS  In Mechanical Engine...
# 4  [{'degree': 'B.Com', 'year': -1, 'marks': '', ...
#
#                                           employment  \
# 0  [{'company_name': 'Aryvart Software Pvt. Ltd',...
# 1  [{'company_name': 'Mphasis', 'from': '01/09/20...
# 2  [{'company_name': 'Nokia Network and solution ...
# 3                                               None
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                                                 contact  \
# 0     {'email1': 'chandreshpas@gmail.com', 'email2':...
# 1     {'email1': 'sreenivas.smsso@gmail.com', 'email...
# 2     {'email1': 'devesh.khanjode@yahoo.com', 'email...
# 3     {'email1': '', 'email2': '', 'phone1': '+91 96...
# 4     {'email1': 'radhakrishnashpk@gmail.com', 'emai...
# 5     {'email1': 'uv.bagwari27@gmail.com', 'email2':...
# 6     {'email1': 'saurabhdarji2110@gmail.com', 'emai...
# 7     {'email1': 'shivamsforcarrer@gmail.com', 'emai...
# 8     {'email1': 'shreekorane09@gmail.com', 'email2'...
# 9     {'email1': 'nrohithkr@gmail.com', 'email2': ''...
# 10    {'email1': 'sanjaypradhan.orcl@gmail.com', 'em...
# 11    {'email1': 'shahmohd082@gmail.com', 'email2': ...
# 12    {'email1': 'anjali.takrani2008@gmail.com', 'em...
# 13    {'email1': 'ammusha@hotmail.com', 'email2': 'a...
# 14    {'email1': 'mail2dharsana@gmail.com', 'email2'...
# ...

# %%
test_df = pd.read_json('testdata.json', lines=True)

# %%
test_df.head(20)
# Out:
#                                            annotation  \
# 0   [{'label': ['Skills'], 'points': [{'start': 12...
# 1   [{'label': ['Email Address'], 'points': [{'sta...
# 2   [{'label': ['Skills'], 'points': [{'start': 37...
# 3   [{'label': ['Skills'], 'points': [{'start': 80...
# 4   [{'label': ['Degree'], 'points': [{'start': 20...
# 5   [{'label': ['Skills'], 'points': [{'start': 28...
# 6   [{'label': ['Skills'], 'points': [{'start': 34...
# 7   [{'label': ['Skills'], 'points': [{'start': 19...
# 8   [{'label': ['Skills'], 'points': [{'start': 17...
# 9   [{'label': ['Skills'], 'points': [{'start': 41...
# 10  [{'label': ['Skills'], 'points': [{'start': 32...
# 11  [{'label': ['Skills'], 'points': [{'start': 23...
# 12  [{'label': ['Skills'], 'points': [{'start': 14...
# 13  [{'label': ['Email Address'], 'points': [{'sta...
# 14  [{'label': ['Skills'], 'points': [{'start': 86...
# 15  [{'label': ['Skills'], 'points': [{'start': 18...
# ...

# %%
test_df.shape
# Out:
# (20, 2)

# %%
site_df = pd.read_json('EntityRecognitioninResumes.json', lines=True)

# %%
site_df.shape
# Out:
# (701, 4)

# %%
site_df.head()
# Out:
#                                           annotation  \
# 0  [{'label': ['Email Address'], 'points': [{'sta...
# 1  [{'label': ['Skills'], 'points': [{'start': 80...
# 2  [{'label': ['Links'], 'points': [{'start': 288...
# 3  [{'label': ['Skills'], 'points': [{'start': 50...
# 4  [{'label': ['Skills'], 'points': [{'start': 19...
#
#                                              content  extras  \
# 0  Afreen Jamadar\nActive member of IIIT Committe...     NaN
# 1  Alok Khandai\nOperational Analyst (SQL DBA) En...     NaN
# 2  Anvitha Rao\nAutomation developer\n\n- Email m...     NaN
# 3  arjun ks\nSenior Program coordinator - oracle ...     NaN
# 4  Arun Elumalai\nQA Tester\n\nChennai, Tamil Nad...     NaN
#
#                                             metadata
# 0  {'first_done_at': 1527844872000, 'last_updated...
# 1  {'first_done_at': 1527845028000, 'last_updated...
# 2  {'first_done_at': 1527744637000, 'last_updated...
# 3  {'first_done_at': 1527834843000, 'last_updated...
# ...

# %%
site_df.drop(['extras', 'metadata'], axis=1)
# Out:
#                                             annotation  \
# 0    [{'label': ['Email Address'], 'points': [{'sta...
# 1    [{'label': ['Skills'], 'points': [{'start': 80...
# 2    [{'label': ['Links'], 'points': [{'start': 288...
# 3    [{'label': ['Skills'], 'points': [{'start': 50...
# 4    [{'label': ['Skills'], 'points': [{'start': 19...
# 5    [{'label': ['Skills'], 'points': [{'start': 17...
# 6    [{'label': ['Skills'], 'points': [{'start': 41...
# 7    [{'label': ['Skills'], 'points': [{'start': 23...
# 8    [{'label': ['Skills'], 'points': [{'start': 14...
# 9    [{'label': ['Email Address'], 'points': [{'sta...
# 10   [{'label': ['Skills'], 'points': [{'start': 86...
# 11   [{'label': ['Skills'], 'points': [{'start': 18...
# 12   [{'label': ['Skills'], 'points': [{'start': 11...
# 13   [{'label': ['Skills'], 'points': [{'start': 46...
# 14   [{'label': ['Skills'], 'points': [{'start': 24...
# 15   [{'label': ['Skills'], 'points': [{'start': 58...
# ...

# %%
site_df.to_json('site_data.json')
